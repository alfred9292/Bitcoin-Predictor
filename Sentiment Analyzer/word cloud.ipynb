# %%
from pandas import read_csv
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alfred/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = read_csv('Regulation.csv',header=0)
reg_news = []
filtered_sentence = [] 
for i in range(0,data.shape[0]):
    x = data.iloc[i].values[2]
    rs=x.replace('\n', '')
    reg_news.append(rs)
text=''
result=''
for i in range(0,len(reg_news)):
   
    reg_news[i]=reg_news[i].replace('\r', '')
    text=text+reg_news[i]

#print(text)

stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(text) 
  
for w in word_tokens: 
    if w not in stop_words: 
        result=result+" "+w 
print(result)
# Out:
#  New York State Department Financial Services ( NYDFS ) Superintendent Benjamin Lawsky today released final version BitLicense regulations , saying “ gut feeling ” digital currencies stay.The BitLicense program require digital currencies businesses New York state operate license report government long making included two revisions comment periods allow public criticism input.Many felt Lawsky find reasonable balance protecting consumers allowing digital finance innovators develop without unnecessary red tape restrictions.Lawsky Defends Need RegulateSaying often “ seems like technologists Venus regulators Mars , ” Lawsky defended need “ protect consumers ” “ root illicit activities. ” Answering criticism anti-money-laundering fraud regulations already existed , maintained digital financial systems different traditional “ disco era ” banking system ’ fit new reality fintech.Changes Final Version BitLicense FrameworkLawsky said five minor changes BitLicense program second third versions 
# ...

# %%
wordcloud=WordCloud().generate(result)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
data2 = read_csv('Privacy & Security .csv',header=0)

sec_news = []
for i in range(0,data2.shape[0]):
    x1 = data2.iloc[i].values[2]
    rs1=x1.replace('\n', '')
    sec_news.append(rs1)
    
text1=''
result1=''
for i in range(0,len(sec_news)):
   
    sec_news[i]=sec_news[i].replace('\r', '')
    text1=text1+sec_news[i]

print(text1)

word_tokens = word_tokenize(text1) 
  
for w in word_tokens: 
    if w not in stop_words: 
        result1=result1+" "+w 
print(result1)
# Out:
# Roughly nine months ago, Bitcoin Foundation Chief Scientist Gavin Andresen made a rather interesting comment on Reddit in which he claimed, “I suspect many [cloud mining companies] will turn out to be Ponzi schemes.”There have been a few cloud mining scams uncovered over the past year or two, and it appears that another one could unravel in the near future. An anonymous source has provided information to Bitcoin Magazine regarding the possibility of a Bitcoin cloud mining ponzi scheme involving Bitcoin Cloud Services (BCS), which is currently one of the largest cloud-mining providers on the market. One of the common attributes of a Ponzi scheme in the Bitcoin world is a reliance on anonymous owners. BTC Cloud Services LTD is registered to Gabriel Kleiman and Esteban Amador Soto Martinez.While the first name does not bring up any identifying information online, the second name is associated with another bitcoin-related scam, bitcoincloudhashing.com. This information is available publi
# ...

# %%
wordcloud=WordCloud().generate(result1)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
data = read_csv('WSJ_news.csv',header=0)
reg_news = []
filtered_sentence = [] 
for i in range(0,data.shape[0]):
    x = data.iloc[i].values[2]
    rs=x.replace('\n', '')
    reg_news.append(rs)
text=''
result=''
for i in range(0,len(reg_news)):
   
    reg_news[i]=reg_news[i].replace('\r', '')
    text=text+reg_news[i]

#print(text)

stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(text) 
  
for w in word_tokens: 
    if w not in stop_words: 
        result=result+" "+w 
print(result)
# Out:
#  A Bitcoin Fund Is Born , With Teething Pains How Future Bitcoin Can Prevent Future GreeceJapanese Police Arrest Mark Karpelès Collapsed Bitcoin Exchange Mt . Gox Former Agent Admits Stealing $ 820,000 Bitcoin , Pleads Guilty Silk Road Probe Visa , Nasdaq , Others Invest $ 30 Million Bitcoin-Related Startup IBM Adapts Bitcoin Technology Smart ContractsTexas Man Admits Bitcoin Ponzi SchemeFollow Money—to Museum NYC Bitcoin Technology Poised Grow , CEO Says Bitcoin Can Be Donated Fidelity Charitable FundCanadian Man Arrested Alleged Role Silk Road AdvisorBitcoin Fund Linked Currency ’ RallyFormer Secret Service Agent Sentenced Stealing BitcoinCentral Bankers Explore Response Bitcoin : Their Own Digital Cash A Vision Money ’ Digital Future , From Cash Code Reported Bitcoin Founder ’ Sydney Home Raided PoliceIs Bitcoin Breaking Up ? Bitcoin Startup Blockstream Raises $ 55 Million Funding RoundIBM Bets Bitcoin Ledger JPMorgan Quietly Tests ‘ Blockchain ’ With 2,200 Clients ‘ Fintech ’ Wil
# ...

# %%
wordcloud=WordCloud().generate(result)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
